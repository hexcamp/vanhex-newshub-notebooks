# %%
import pyodide_http

# %%
pyodide_http.patch_all()

# %%
import requests

# %%
# %pip install -q readability-lxml

# %%
# %pip install -q lxml_html_clean==0.4.4

# %%
from readability import Document

# %%
url="https://127.0.0.1:8092/2026-06-16/https://globalnews.ca/news/11908127/metro-vancouver-outside-workers-union-mediated-talks/"

# %%
url="https://127.0.0.1:8092/2026-06-16/https://thetyee.ca/News/2026/06/16/DoorDash-Uber-Try-Halt-Gig-Worker-Protection/?utm_source=bluesky&utm_medium=social&utm_campaign=editorial"

# %%
url
# Out:
# 'https://127.0.0.1:8092/2026-06-16/https://thetyee.ca/News/2026/06/16/DoorDash-Uber-Try-Halt-Gig-Worker-Protection/?utm_source=bluesky&utm_medium=social&utm_campaign=editorial'

# %% [markdown]
# [Documentation: python-readability](https://github.com/buriy/python-readability/tree/master#usage)

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text[0:200]
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class='

# %%
response.content[0:200]
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class='

# %%
doc = Document(response.text)

# %%
doc

# %%
doc.title()
# Out:
# 'DoorDash and Uber Try to Halt the Spread of Gig Worker Protection | The Tyee'

# %%
doc.summary()
# Out:
# '<html><body><div><div class="container-fluid clearfix ">\n            \n\n  \n\n\n\n\n\n\n      \n\n\n\n\n\n\n                          <p class="lead-in"><a href="https://127.0.0.1:8092/2026-06-16/https://www.harpergrey.com/workplace-law/bc-is-the-first-jurisdiction-in-canada-to-provide-basic-protections-for-gig-workers/">British Columbia</a> and <a href="https://127.0.0.1:8092/2026-06-16/https://www.ontario.ca/page/rights-and-protections-digital-platform-workers">Ontario</a> have enacted laws that extend some protections to gig workers, and platform giants like Uber and DoorDash appear to be lobbying to keep similar policies from being adopted in other provinces.</p>\n\n                                  <p>Ride-hailing and delivery drivers for digital platforms in North America are classified as independent contractors and not employees of the companies they work for. While app giants argue this arrangement allows greater flexibility, it also means workers aren’t entitled to basic
# ...

# %%
file_out = open("simplified.html", "w")
file_out.write(doc.summary())
file_out.close()
